# %%
from ultralytics import YOLO

model = YOLO('model/yolo26n.pt')

# %%
results = model.train(
    data='dataset/data.yaml',
    epochs=100,
    imgsz=640,
    batch=16,
    device='0'
)
# Out:
# Ultralytics 8.4.8 🚀 Python-3.10.19 torch-2.9.1+cu128 CUDA:0 (Tesla V100-SXM2-16GB, 16144MiB)
# ...
